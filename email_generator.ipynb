# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.1-70b-versatile"
)
response = llm.invoke("The first person to rule morocco  by Alawi dynasty...")
print(response.content)
# Out:
# The first person to rule Morocco from the Alaouite dynasty (also known as the Alawi dynasty) was Moulay Ali Cherif, but he is not well-known.
#
# However, the founder of the Alaouite dynasty and the first prominent ruler is Moulay Ali Cherif's grandson, Moulay Ali Cherif's son's son:
#
# Moulay Ali Cherif's son: Moulay Muhammad
# Moulay Muhammad's son: Moulay Al-Rashid
#
# Moulay Al-Rashid (1631-1672) is often considered the first ruler of the Alaouite dynasty of Morocco. He was the son of Moulay Muhammad and the grandson of Moulay Ali Cherif. He united Morocco under his rule and established the Alaouite dynasty, which still rules Morocco today.

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\jam13\anaconda3\lib\site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (0.3.29)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (0.2.10)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\jam13\anaconda3\lib\site-packages (from langchain_community) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jam13\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jam13\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.24.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\jam13\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.14->langchain_community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jam13\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.14->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jam13\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jam13\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jam13\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jam13\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain_community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jam13\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain_community) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jam13\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\jam13\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jam13\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jam13\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jam13\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jam13\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jam13\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\jam13\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jam13\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\jam13\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jam13\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jam13\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain_community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jam13\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain_community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jam13\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/fr/job/R-45775?from=job%20search%20funnel")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Postuler pour Data Engineer
#
# Rechercher des postesPasser la navigationRechercher des postesNIKE, INC. JOBSEmplois temporairesJoin The Talent CommunityNike au quotidienPrésentationAvantages sociauxMarquesPrésentationJordanConverseÉquipesPrésentationSoutien administratifInnovation de pointeAir Manufacturing et InnovationAéronautiqueCommunicationsService clientConceptionNumériqueInstallationsFinance et comptabilitéAffaires gouvernementales et publiquesRessources humainesDonnées et analyseService juridiqueFabrication et ingénierieMarketingMerchandisingPlanificationConfidentialitéAchatsCréation, développement et gestion de produitsService de gestion des magasinsMagasinsVentesImpact social et communautaireMarketing sportsPlanification stratégiqueChaîne d'approvisionnement, distribution et logistiqueDurabilitéTechnologieSitesPrésentationNike WHQSiège de Nike à New YorkEHQ : Hilversum, Pays-BasELC: Laakdal, BelgiumGreater China HQDiversité, égalité et inclusivitéPrésentationMilitaryHandicap et inclusionInclusion autochtonesStagesData & AnalyticsData EngineerBeaverton, OregonRejoignez l'équipe NIKE, Inc.
# Loin de se contenter d'équiper les plus grands athlètes mondiaux, NIKE, Inc. explore les potentiels, abolit les frontières et repousse les limites du possible. L'entreprise recherche des personnes capables d'évoluer, de réfléchir, de rêver et de créer. L'épanouissement de sa culture repose sur son ouverture à la diversité et sur sa façon d'encourager l'imagination. La marque a besoin de personnes talentueuses, de leaders et de visionnaires. Chez NIKE, Inc., chacun contribue, par ses compétences et sa passion, à jouer un match difficile en constante évolution.Data Engineer - NIKE, Inc. - Beaverton, OR. Design and implement features in collaboration with product owners, data analysts, and business partners using Agile / Scrum methodology; contribute to overall architecture, frameworks and patterns for processing and storing large data volumes; design and implement distributed data processing pipelines using tools and languages prevalent in the Hadoop or Cloud ecosystems; build utilities, user defined functions, and frameworks to better enable data flow patterns; build and develop job orchestration and scheduling using Airflow; research, evaluate and utilize new technologies/tools/frameworks centered around high-volume data processing; define and apply appropriate data acquisition and consumption strategies for given technical scenarios; build and incorporate automated unit tests and participate in integration testing efforts; work with architecture/engineering leads and other teams to ensure quality solutions are implemented, and engineering best practices are defined and adhered to; and work across teams to resolve operational and performance issues. Telecommuting is available from anywhere in the U.S., except from AK, AL, AR, DE, HI, IA, ID, IN, KS, KY, LA, MT, ND, NE, NH, NM, NV, OH, OK, RI, SD, VT, WV, and WY.  Employer will accept a Bachelor’s degree in Computer Science or Information Technology and two (2) years of experience in the job offered or in an engineering-related occupation.   Experience must include the following:  Python SQL Apache Hadoop Apache Hive AWS Airflow Databricks Apache Spark Teradata Snowflake Kinesis Lamdba EMR  Apply at www.jobs.nike.com (Job #R-45775).#LI-DNIWe are committed to fostering a diverse and inclusive environment for all employees and job applicants. We offer a number of accommodations to complete our interview process including screen readers, sign language interpreters, accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as needed. If you discover, as you navigate our application process, that you need assistance or an accommodation due to a disability, please complete the Candidate Accommodation Request Form.NIKE, Inc. est une entreprise en pleine croissance cherchant à intégrer à son équipe des personnes capables de se développer avec elle. Nike offre un généreux programme de rémunération globale, un environnement de travail décontracté, une culture variée et inclusive et une atmosphère dynamique propice au développement professionnel. Quels que soient le site ou le poste, les employés de Nike partagent tous la même mission stimulante : apporter inspiration et innovation aux athlètes* du monde entier.NIKE, Inc. s'engage à embaucher un personnel diversifié. Les candidats qualifiés seront considérés sans tenir compte de leur origine, couleur de peau, religion, sexe, nationalité, âge, orientation sexuelle, identité de genre, expression de genre, statut de vétéran ou handicap.Notre stratégie de recrutementNIKE, Inc. met tout en œuvre pour proposer une expérience de candidature qualitative, inclusive, intéressante et authentique. Pour ce faire, nous vous aidons à venir avec les meilleurs atouts possibles, et donc à comprendre comment fonctionne notre processus d'embauche. La transparence est essentielle.
#
# * Cette présentation explique notre processus de recrutement pour les postes basés dans nos bureaux. Il est possible que les étapes de recrutement soient différentes pour les postes basés ailleurs que dans nos bureaux.Commencer maintenantAvantages sociauxDes transports aux avantages financiers, nous investissons en permanence dans le bien-être de nos employés pour les aider à exceller en tous points, au travail comme dans la sphère privée. Tous ceux qui travaillent chez Nike devraient pouvoir exploiter pleinement leur potentiel.Programme d'aide aux employésPlan d'actionnariat salariéJours fériésCouverture médicaleCongés payésRéductions sur les produitsCongés sabbatiquesEn savoir plusCARTES CADEAUXTROUVER UN MAGASINNIKE JOURNALDEVENIR MEMBRERÉDUCTION POUR ÉTUDIANTSCOMMENTAIRESCODES PROMOAIDEAIDEStatut de commandeExpédition et livraisonRetoursModes de paiementNous contacterAide - Codes promo NikeÀ PROPOS DE NIKEÀ PROPOS DE NIKEActualitésCarrièresInvestisseursDéveloppement durableAPPLICATIONS NIKEAPPLICATIONS NIKENike AppNike Run ClubNike Training ClubSNKRSFrance© 2025 Nike, Inc. Tous droits réservésGuidesNike AdaptNike FlyEaseNike FreeNike VaporflyÉquipement de fan NBANike AirNike FlyKnitNike PegasusNike Zoom FlyFactory StoreNike Air MaxNike FlyleatherNike ReactNike ZoomXKids AirtopiaConditions d'utilisationConditions générales de venteMentions légalesPolitique en matière de confidentialité et de cookiesParamètres des cookies

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})



json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Data Engineer',
#  'experience': '2 years',
#  'skills': ['Python',
#   'SQL',
#   'Apache Hadoop',
#   'Apache Hive',
#   'AWS',
#   'Airflow',
#   'Databricks',
#   'Apache Spark',
#   'Teradata',
#   'Snowflake',
#   'Kinesis',
#   'Lambda',
#   'EMR'],
#  'description': 'Design and implement features in collaboration with product owners, data analysts, and business partners using Agile / Scrum methodology; contribute to overall architecture, frameworks and patterns for processing and storing large data volumes; design and implement distributed data processing pipelines using tools and languages prevalent in the Hadoop or Cloud ecosystems; build utilities, user defined functions, and frameworks to better enable data flow patterns; build and develop job orchestration and scheduling using Airflow; research, evaluate and utilize new technologies/tools/frameworks centered around high-volume data processing; define and apply appropriate data acquisition and consumption strategies for given technical scenarios; build and incorporate automated unit tests and participate in integration testing efforts; work with architecture/engineering leads and other teams to ensure quality solutions are implemented, and engineering best practices are defined and adhered to; and work across teams to resolve operational and performance issues.'}

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
# 20           Apache Spark, Hadoop, Kafka
# 21                 Python, Pandas, NumPy
# 22                     AWS, Redshift, S3
# 23             Google BigQuery, Dataflow
# 24                        Snowflake, dbt
# 25                SQL, PostgreSQL, MySQL
# 26                      Airflow, Prefect
# 27                     Tableau, Power BI
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio
# 20                          https://spark.apache.org/
# 21                         https://pandas.pydata.org/
# 22                            https://aws.amazon.com/
# 23                  https://cloud.google.com/bigquery
# 24                         https://www.snowflake.com/
# 25                        https://www.postgresql.org/
# 26                        https://airflow.apache.org/
# 27                           https://www.tableau.com/

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\jam13\anaconda3\lib\site-packages (0.6.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\jam13\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (3.7.5)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (1.69.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (3.10.13)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jam13\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\jam13\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\jam13\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\jam13\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\jam13\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in c:\users\jam13\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\jam13\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\jam13\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\jam13\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\jam13\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jam13\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\jam13\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\jam13\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jam13\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.12.23)
# Requirement already satisfied: protobuf in c:\users\jam13\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.2)
# Requirement already satisfied: sympy in c:\users\jam13\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\jam13\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\jam13\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\jam13\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jam13\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jam13\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jam13\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jam13\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\jam13\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\jam13\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jam13\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\jam13\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\jam13\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\jam13\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in c:\users\jam13\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jam13\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jam13\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jam13\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\jam13\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jam13\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jam13\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jam13\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jam13\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jam13\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jam13\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\jam13\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jam13\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
job = json_res
job['skills']
# Out:
# ['Python',
#  'SQL',
#  'Apache Hadoop',
#  'Apache Hive',
#  'AWS',
#  'Airflow',
#  'Databricks',
#  'Apache Spark',
#  'Teradata',
#  'Snowflake',
#  'Kinesis',
#  'Lambda',
#  'EMR']

# %%
job
# Out:
# {'role': 'Data Engineer',
#  'experience': '2 years',
#  'skills': ['Python',
#   'SQL',
#   'Apache Hadoop',
#   'Apache Hive',
#   'AWS',
#   'Airflow',
#   'Databricks',
#   'Apache Spark',
#   'Teradata',
#   'Snowflake',
#   'Kinesis',
#   'Lambda',
#   'EMR'],
#  'description': 'Design and implement features in collaboration with product owners, data analysts, and business partners using Agile / Scrum methodology; contribute to overall architecture, frameworks and patterns for processing and storing large data volumes; design and implement distributed data processing pipelines using tools and languages prevalent in the Hadoop or Cloud ecosystems; build utilities, user defined functions, and frameworks to better enable data flow patterns; build and develop job orchestration and scheduling using Airflow; research, evaluate and utilize new technologies/tools/frameworks centered around high-volume data processing; define and apply appropriate data acquisition and consumption strategies for given technical scenarios; build and incorporate automated unit tests and participate in integration testing efforts; work with architecture/engineering leads and other teams to ensure quality solutions are implemented, and engineering best practices are defined and adhered to; and work across teams to resolve operational and performance issues.'}

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/java-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/flutter-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/vue-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}]]

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Jamal, a business development executive at MarrakechiQ. MarrakechiQ is an AI & Software Consulting Agency dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of MarrakechiQ
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase MarrakechiQ's portfolio: {link_list}
        Remember you are Jamal, BDE at MarrakechiQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Data Engineering Solutions for Seamless Business Integration
#
# Dear Hiring Manager,
#
# I came across your job posting for a Data Engineer and was impressed by the role's requirements and responsibilities. As a Business Development Executive at MarrakechiQ, I'd like to introduce our company's capabilities in fulfilling your data engineering needs.
#
# At MarrakechiQ, we specialize in AI and software consulting, empowering enterprises with tailored solutions that foster scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts has extensive experience in designing and implementing features using Agile/Scrum methodology, contributing to overall architecture, frameworks, and patterns for processing and storing large data volumes.
#
# We've successfully delivered projects involving distributed data processing pipelines using tools like Apache Hadoop, Apache Spark, and Cloud ecosystems. Our expertise in building utilities, user-defined functions, and frameworks enables efficient data flow patterns. We're also proficient in job orchestration and scheduling using Airflow, as well as researching and evaluating new technologies centered around high-volume data processing.
#
# Our portfolio showcases our capabilities in:
#
# * Machine learning and Python development: https://example.com/ml-python-portfolio
# * Python-based solutions: https://example.com/python-portfolio
# * DevOps and automation: https://example.com/devops-portfolio
#
# We're confident that our team can design and implement features that meet your requirements, collaborate with your product owners, data analysts, and business partners, and contribute to the overall architecture and frameworks for processing and storing large data volumes.
#
# I'd be delighted to schedule a call to discuss how MarrakechiQ can support your data engineering needs and provide a customized solution that aligns with your business goals. Please let me know if you're interested, and I'll send over some availability.
#
# Looking forward to the opportunity to collaborate and drive business success together.
#
# Best regards,
#
# Jamal
# Business Development Executive
# MarrakechiQ
